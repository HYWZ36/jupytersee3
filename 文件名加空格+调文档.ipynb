# %%
#coding=utf-8
# 加空格
import sys
reload(sys)
sys.setdefaultencoding('utf8')
from docx import Document
from docx.shared import RGBColor, Pt, Cm, Inches
import os
import glob
from docx.oxml.ns import qn
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Length
from docx.enum.text import WD_LINE_SPACING
# print(3)
path = r"E:\118wendang\0129企业计划-完-docx\800-改变"
path=path.encode('gbk')
i =0
# print(3)
for root, subdirs, files in os.walk(path):
    root = root.decode('gbk')
    for name in files:
        i=i+1
# #         尾部随机加空格法
# #             i%x,则空格以x个文档为单位不断循环产生x=3,2
        index0 = 8-i%2

#         首部加空格法
#         尝试在首部加字符
#         index0 = 0
#         print(name)
        oldname = unicode(name,'gbk')
#             print(oldname)
        try:
#                 a=1
#             空格数量添加法
#             可以加1个或多个空格符
            newname = oldname[:-index0]+' '+oldname[-index0:]
            os.rename(os.path.join(root, oldname), os.path.join(root, newname))
            # print(newname)
        except:
            pass

# %%
#coding=utf-8
import sys
reload(sys)
sys.setdefaultencoding('utf8')
# 另存为docx文件
import os #用于获取目标文件所在路径
from win32com import client as wc #导入模块
from multiprocessing.dummy import Pool as Threadpool
import pythoncom
import time

class Document(object):
    def __init__(self):
        # 文件夹绝对路径
        self.__path__ = "E:\\118wendang\\0130学校计划\\0218-300-docx\\"
        # self.__path__ = "E:\\118wendang啊\\"
        self.__path__ = self.__path__.decode('utf-8')
        self.__files__ = []

    def append_doc(self):
        for file in os.listdir(self.__path__):
            # file = file.decode('gbk')
            # 排除文件夹内的其它干扰文件，只获取".doc"后缀的word文件
            if file.endswith(".doc"):
                self.__files__.append(self.__path__+file)
                # print("doc文档：")
                # print(files)
        return self.__files__

    # 参数分别是单个文件名和word应用程序
    def convert_docx(self, filenames):
        pythoncom.CoInitialize()
        # 打开word应用程序，坚决别用word，使用wps
        word = wc.Dispatch("kwps.Application")
        # filename = filenames.decode('utf-8').encode('gbk')
        filename = filenames.decode('utf-8').encode('gbk')
        # filename = filenames.encode('utf-8').decode('gbk')
        # filename = filenames
        # 打开word文件
        doc = word.Documents.Open(filename)
        # 另存为后缀为".docx"的文件，其中参数12指docx文件
        doc.SaveAs("{}x".format(filename), 12)
        # doc.SaveAs("{}x".format(filename), 12)
        doc.Close()  # 关闭原来word文件
        # word.Quit()
        # return word
        # print("完成！")


# 参数分别是单个文件名和word应用程序
def convert_docx(filenames):
    # 打开word应用程序，坚决别用word，使用wps
    word = wc.Dispatch("kwps.Application")
    # filename = filenames.decode('utf-8').encode('gbk')
    # 好的编码问题解决办法就是排列组合实验法
    filename = filenames.decode('utf-8').encode('gbk')
    # filename = filenames.encode('utf-8').decode('gbk')
    # filename = filenames
    # 打开word文件
    doc = word.Documents.Open(filename)
    # 另存为后缀为".docx"的文件，其中参数12指docx文件
    doc.SaveAs("{}x".format(filename), 12)
    # doc.SaveAs("{}x".format(filename), 12)
    doc.Close() #关闭原来word文件
    # word.Quit()
    # return word
    # print("完成！")


if __name__ == "__main__":
    list_filename = []
    doc = Document()
    list_filename = doc.append_doc()
    from multiprocessing import cpu_count
    from multiprocessing import Pool
    # print("cpu个数:",cpu_count())  #获取CPU个数

    # 进程池法，不能再进程池中调用类函数doc.convert_docx，因此单独定义函数convert_docx
    # time_start = time.time()
    # ps = Pool(10) #设置进程池
    # for i in list_filename:
    #     # convert_docx(i)
    #     # 异步执行
    #     ps.apply_async(convert_docx, args=(i,))
    #     # 同步执行
    #     # ps.apply(convert_docx, args=(i,))
    # ps.close()
    # ps.join()
    # time_end = time.time()
    # word = wc.Dispatch("kwps.Application")
    # word.Quit()
    # print("完成，用时",time_end-time_start,"s")

    # 线程池法，可在线程池中调用类函数doc.convert_docx
    time_start = time.time()
    # 会出错
    pool = Threadpool(10)
    pool.map(doc.convert_docx, list_filename)
    pool.close()
    pool.join()
    time_end = time.time()
    word = wc.Dispatch("kwps.Application")
    word.Quit()
    print("完成，用时",time_end-time_start,"s")
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-1-bc80b4f191cd> in <module>()
#      96     # 会出错
#      97     pool = Threadpool(10)
# ---> 98     pool.map(doc.convert_docx, list_filename)
#      99     pool.close()
#     100     pool.join()
#
# d:\python27\lib\multiprocessing\pool.pyc in map(self, func, iterable, chunksize)
#     251         '''
#     252         assert self._state == RUN
# --> 253         return self.map_async(func, iterable, chunksize).get()
#     254
#     255     def imap(self, func, iterable, chunksize=1):
#
# d:\python27\lib\multiprocessing\pool.pyc in get(self, timeout)
#     570             return self._value
#     571         else:
# --> 572             raise self._value
#     573
#     574     def _set(self, i, obj):
#
# ...

# %%
# 转doc为docx 宏命令
Sub doc2docx()    'doc文件转docx文件

Dim myDialog As FileDialog, oFile As Variant

Set myDialog = Application.FileDialog(msoFileDialogFilePicker)

With myDialog

        .Filters.Clear    '清除所有文件筛选器中的项目

        .Filters.Add "所有 WORD2007 文件", "*.doc", 1    '增加筛选器的项目为所有WORD2007文件

        .AllowMultiSelect = True    '允许多项选择

        If .Show = -1 Then    '确定

            For Each oFile In .SelectedItems    '在所有选取项目中循环

                With Documents.Open(oFile)
                
                .SaveAs FileName:=oFile + "x", FileFormat:=12

                .Close

                End With

            Next

        End If

End With

End Sub

# %%
# coding=utf-8
# 文档内容处理
import sys
reload(sys)
sys.setdefaultencoding('utf8')
from docx import Document
from docx.shared import RGBColor, Pt, Cm, Inches
import os
import glob
from docx.oxml.ns import qn
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Length
from docx.enum.text import WD_LINE_SPACING
from win32com import client as wc #导入模块
from multiprocessing.dummy import Pool as Threadpool
import pythoncom
import time

class Documents(object):
    def __init__(self):
        self.__files__ = []
        # 原文件路径
        self.__path__ = r'D:\\0129医院总结-完-1006docx - 副本\\'
        self.__path__ = self.__path__.encode('gbk')
        # 新文件路径
        self.__mkdir_path__ = r'D:\\0129医院总结-完-1006docx - 副本改变\\'
        self.__mkdir_path__ = self.__mkdir_path__.encode('gbk')
        if not os.path.exists(self.__mkdir_path__):
            os.mkdir(self.__mkdir_path__)
        
        self.__dict0__ = {'教学': '讲学'}
#                 self.__dict0__['教学']='讲学'          
        self.__dict0__['老师']='讲师'  
        self.__dict0__['工作']='作业'  

        self.__dict0__['事情']='作业'  
        self.__dict0__['很']='甚'  
        self.__dict0__['通过']='经过'  
        self.__dict0__['努力']='勤勉'  
        self.__dict0__['只有']='惟有'  
        self.__dict0__['是']='乃是'  
        self.__dict0__['感受']='感想'  
        self.__dict0__['原则']='准绳'  
        self.__dict0__['能力']='本领'  
        self.__dict0__['提高']='拔高'  
        self.__dict0__['管理']='治理'  
        self.__dict0__['可以']='能够'  
        self.__dict0__['核心']='重心'  
        self.__dict0__['深入']='深刻'  
        self.__dict0__['目标']='宗旨'  
        self.__dict0__['宣传']='宣扬'  
        self.__dict0__['参考']='参阅'  
        self.__dict0__['特点']='特性'  
        self.__dict0__['成立']='确立'  
        self.__dict0__['培养']='培育'  
        self.__dict0__['考察']='审查'  
        self.__dict0__['邀请']='诚邀'  
        self.__dict0__['检查']='稽查'  
        self.__dict0__['全面']='通盘'  
        self.__dict0__['解答']='解读回答'  
        self.__dict0__['提供']='供予'    
        self.__dict0__['提升']='拔高'  
        self.__dict0__['非常']='甚是'    
        self.__dict0__['我们']='俺们' 
        self.__dict0__['目的']='宗旨' 

        # self.__dict0__['选择题']='选择题目'
        # self.__dict0__['了']=''
        # self.__dict0__['有']='拥有'
#         self.__dict0__['则'] = '那么'
# #         self.__dict0__['为'] = '是'
# #         self.__dict0__['那么'] = '则'
#         self.__dict0__['中'] = '之中'
#         self.__dict0__['若'] = '如果'
#         # self.__dict0__['解答题']='解答题目'
#         self.__dict0__['公路'] = '道路'
#         self.__dict0__['已知'] = '已经知道'
#         self.__dict0__['图像'] = '图形'
#         self.__dict0__['图象'] = '图形'
#         self.__dict0__['根据'] = '依照'
#         self.__dict0__['练习'] = '演练'
#         self.__dict0__['训练']='演练'
#         self.__dict0__['解析式']='表达式'
#         self.__dict0__['个人']='人员'
#         self.__dict0__['年终']='年尾'
#         self.__dict0__['工作总结']='工作梳理'
#         self.__dict0__['工作计划']='劳动计划'
#         self.__dict0__['忙忙碌碌']='马不停蹄'
#         self.__dict0__['公司']='企事业单位'
#         self.__dict0__['担任']='负责任职'
#         self.__dict0__['部门']='团队组织'
#         self.__dict0__['非常']='异常'
#         self.__dict0__['感觉']='认为'
#         self.__dict0__['工作']='任职事务'
#         self.__dict0__['目的']='目标'
#         self.__dict0__['教训']='失败或痛苦'
#         self.__dict0__['提高']='提升'
#         self.__dict0__['做']='作'
#         self.__dict0__['更好']='更优'
#         self.__dict0__['简要']='扼要'
#         self.__dict0__['不足']='缺陷'
#         self.__dict0__['效率']='效果'
#         self.__dict0__['特点']='特性'
#         self.__dict0__['全面']='全盘'
#         self.__dict0__['教育']='教导'
#         self.__dict0__['扎实']='踏实'
#         self.__dict0__['思想']='思维'
#         self.__dict0__['更新']='刷新'
#         self.__dict0__['狠抓']='严抓'
#         self.__dict0__['主要']='关键'
#         self.__dict0__['学校']='校园'
#         self.__dict0__['基本']='基础'
        
#         self.__dict0__['教学']='教育'        
#         self.__dict0__['工作']='作业'
#         self.__dict0__['事情']='作业'
#         self.__dict0__['很多']='许多'
#         self.__dict0__['通过']='经过'
#         self.__dict0__['努力']='尽力'
#         self.__dict0__['只有']='只要'
#         self.__dict0__['就是']='便是'
#         self.__dict0__['感受']='感触'
#         self.__dict0__['原则']='准则'
#         self.__dict0__['能力']='才能'
#         self.__dict0__['提高']='进步'
#         self.__dict0__['管理']='办理'
#         self.__dict0__['确保']='保证'
#         self.__dict0__['贯彻']='遵循'
#         self.__dict0__['制度']='准则'
#         self.__dict0__['思想']='思维'
#         self.__dict0__['素养']='本质'
#         self.__dict0__['核心']='中心'
#         self.__dict0__['基']='根'
#         self.__dict0__['深入']='深化'
#         self.__dict0__['目标']='方针'
#         self.__dict0__['建设']='建造'
#         self.__dict0__['办好']='办妥'
#         self.__dict0__['宣传']='宣扬'
#         self.__dict0__['渗透']='浸透'
#         self.__dict0__['寝室']='睡房'
#         self.__dict0__['战斗']='战役'
#         self.__dict0__['成立']='树立'
#         self.__dict0__['培养']='培育'
#         self.__dict0__['考察']='调查'
#         self.__dict0__['示范']='演示'
#         self.__dict0__['责任']='职责'
#         self.__dict0__['组织']='安排'
#         self.__dict0__['契机']='关键'
#         self.__dict0__['认识']='知道'
#         self.__dict0__['邀请']='邀约'
#         self.__dict0__['内外']='表里'
#         self.__dict0__['检查']='查看'
#         self.__dict0__['辅导']='教导'
#         self.__dict0__['建立']='树立'
#         self.__dict0__['互助']='合作'
#         self.__dict0__['老师']='教师'
#         self.__dict0__['解答']='回答'
#         self.__dict0__['沟通']='交流'
#         self.__dict0__['反馈']='反映'
#         self.__dict0__['召开']='举行'
#         self.__dict0__['依靠']='依托'
#         self.__dict0__['提升']='提高'
#         self.__dict0__['毕业']='结业'
#         self.__dict0__['事务']='业务'
#         self.__dict0__['整理']='收拾'
#         self.__dict0__['联系']='联络'
#         self.__dict0__['提供']='供给'
#         self.__dict0__['参考']='参阅'
#         self.__dict0__['材料']='资料'
#         self.__dict0__['时时']='不时'
#         self.__dict0__['规范']='标准'
#         self.__dict0__['记录']='记载'
#         self.__dict0__['谈话']='说话'
#         self.__dict0__['任务']='使命'
#         self.__dict0__['一样']='相同'
#         self.__dict0__['繁重']='深重'
#         self.__dict0__['我们']='咱们'
#         self.__dict0__['需要']='需求'
#         self.__dict0__['可以']='能够'
#         self.__dict0__['时间']='时刻'
#         self.__dict0__['就是']='便是'
#         self.__dict0__['锻炼']='训练'
#         self.__dict0__['以后']='今后'
        
        
        
        
        # dict0


    def append_doc(self):
        for file in os.listdir(self.__path__):
            # file = file.decode('gbk')
            # 排除文件夹内的其它干扰文件，只获取".doc"后缀的word文件
            # if file.endswith(".docx"):
            self.__files__.append(self.__path__+file)
            # print("doc文档：")
            # print(files)
        return self.__files__

    # 修改文档
    def contentModify(self, file):
        try:
            docx = Document(file)
            # 【1】修改关键字
            """
                遍历word中的所有 paragraphs，在每一段中发现含有key 的内容，就替换为 value 。 
                （key 和 value 都是replace_dict中的键值对。）
            """
            for para in docx.paragraphs:
                for i in range(len(para.runs)):
                    for key, value in self.__dict0__.items():
                        if key in para.runs[i].text:
                            # print(key + "-->" + value)
                            para.runs[i].text = para.runs[i].text.replace(key, value)

#             # 修改段落距离等信息
#             # 较大范围内的修改必须在尾部，在首部修改无效
#             # 【2】修改段间距，以榜为单位
#             pars=docx.paragraphs
#             for par in pars:
#                 if par.style.name=="Heading 1":
#                     par.paragraph_format.space_before = Pt(18)
#                     par.paragraph_format.space_after =Pt(18)
#                 # 【3】段落首行缩进
#                 par.paragraph_format.first_line_indent = Inches(0.25)
#                 #  【4】段落对齐方式
#                 # LEFT      =>  左对齐
#                 # CENTER    =>  文字居中
#                 # RIGHT     =>  右对齐
#                 # JUSTIFY   =>  文本两端对齐
#                 par.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.JUSTIFY
#                 # 【5】段落行距
#                 #SINGLE         =>  单倍行距（默认）
#                 #ONE_POINT_FIVE =>  1.5倍行距
#                 #DOUBLE2        =>  倍行距
#                 #AT_LEAST       =>  最小值
#                 #EXACTLY        =>  固定值
#                 #MULTIPLE       =>  多倍行距
#                 par.line_spacing_rule = WD_LINE_SPACING.MULTIPLE #多倍行距
#                 par.paragraph_format.line_spacing = 1.75 # 1.75倍行间距

#             # 修改字体信息
#             # 【6】 修改正文的中文字体大小，字体类型无法修改
#             docx.styles['Normal'].font.name = u'微软雅黑'
#             docx.styles['Normal']._element.rPr.rFonts.set(qn('w:eastAsia'), u'微软雅黑')
#             docx.styles['Normal'].font.size = Pt(12.8)
    #         保存文档
            docx.save(self.__mkdir_path__ + '/' + os.path.basename(file))
        except:
#             print(1)
            pass
        
if __name__ == "__main__":    
#     print(2)
    list_filename = []
    doc = Documents()
    list_filename = doc.append_doc()

    # 线程池法，可在线程池中调用类函数doc.convert_docx
    time_start = time.time()
#     print(2)
    pool = Threadpool(5)
#     print(3)
    pool.map(doc.contentModify, list_filename)
    pool.close()
    pool.join()
    time_end = time.time()
    word = wc.Dispatch("kwps.Application")
    word.Quit()
    print("完成，用时",time_end-time_start,"s")

# %%
# 多余的操作实例
import sys
reload(sys)
sys.setdefaultencoding('utf8')
from docx import Document  
from docx.oxml.ns import qn  
from docx.shared import Pt,RGBColor
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Length
from docx.enum.text import WD_LINE_SPACING

Doc = Document()  
Doc.add_heading(u"刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了刚来csdn，这就是博客么，I了")  
Doc.add_paragraph(u"Python ")  
Doc.add_paragraph(u"Python 对word进行操作")
# 修改段间距，以榜为单位
pars=Doc.paragraphs
for par in pars:
    if par.style.name=="Heading 1":
        par.paragraph_format.space_before = Pt(18)
        par.paragraph_format.space_after =Pt(18)
#     段落首行缩进
    par.paragraph_format.first_line_indent = Inches(-0.25)
    #     段落对齐方式 
    # LEFT      =>  左对齐
    # CENTER    =>  文字居中
    # RIGHT     =>  右对齐
    # JUSTIFY   =>  文本两端对齐
    par.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.JUSTIFY
#     段落行距
    #SINGLE         =>  单倍行距（默认）
    #ONE_POINT_FIVE =>  1.5倍行距
    #DOUBLE2        =>  倍行距
    #AT_LEAST       =>  最小值
    #EXACTLY        =>  固定值
    #MULTIPLE       =>  多倍行距
#     par.line_spacing_rule = WD_LINE_SPACING.EXACTLY #固定值
#     par.paragraph_format.line_spacing = Pt(18) # 固定值18磅
    par.line_spacing_rule = WD_LINE_SPACING.MULTIPLE #多倍行距
    par.paragraph_format.line_spacing = 1.75 # 1.75倍行间距
    # paragraph = Doc.add_paragraph(u'这是一个样式为 ListBullet 的段落')
    # paragraph.style = 'List Bullet'


Doc.styles['Normal'].font.name = u'微软雅黑'  
Doc.styles['Normal']._element.rPr.rFonts.set(qn('w:eastAsia'), u'微软雅黑')  
Doc.styles['Normal'].font.size = Pt(20)  
Doc.styles['Normal'].font.color.rgb = RGBColor(0,0,0)

Doc.save(r'E:\118wendang_new\11.docx')

# %%
import time
import random

for i in range(10):
    num = random.randint(2,4) + random.random()
    print(num)
    time.sleep(num)
    print(i)
# Out:
# 2.45163297152
# 0
# 2.03243515793
# 1
# 4.98519991219
# 2
# 4.38140167536
# 3
# 2.36738965373
# 4
# 4.91961522317
# 5
# 3.44739969197
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2d2a02827b5e> in <module>()
#       5     num = random.randint(2,4) + random.random()
#       6     print(num)
# ----> 7     time.sleep(num)
#       8     print(i)
#
# KeyboardInterrupt:

# %%
# coding=utf-8
# 文档内容处理
import sys

reload(sys)
sys.setdefaultencoding('utf8')
from docx import Document
from docx.shared import RGBColor, Pt, Cm, Inches
import os
import glob
from docx.oxml.ns import qn
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Length
from docx.enum.text import WD_LINE_SPACING
from win32com import client as wc  # 导入模块
from multiprocessing.dummy import Pool as Threadpool
import pythoncom
import time


class Documents(object):
    def __init__(self):
        self.__files__ = []
        # 原文件路径
        self.__path__ = r'C:\\Users\\wangze\\Downloads\\测试文章\\'
        self.__path__ = self.__path__.encode('gbk')
        # 新文件路径
        self.__mkdir_path__ = r'C:\\Users\\wangze\\Downloads\\\测试文章 - 副本\\'
        self.__mkdir_path__ = self.__mkdir_path__.encode('gbk')
        if not os.path.exists(self.__mkdir_path__):
            os.mkdir(self.__mkdir_path__)

        self.__dict0__ = {'教学': '讲学'}
        #                 self.__dict0__['教学']='讲学'
        self.__dict0__['老师'] = '讲师'
        self.__dict0__['工作'] = '作业'

        self.__dict0__['事情'] = '作业'
        self.__dict0__['很'] = '甚'
        self.__dict0__['通过'] = '经过'
        self.__dict0__['努力'] = '勤勉'
        self.__dict0__['只有'] = '惟有'
        self.__dict0__['是'] = '乃是'
        self.__dict0__['感受'] = '感想'
        self.__dict0__['原则'] = '准绳'
        self.__dict0__['能力'] = '本领'
        self.__dict0__['提高'] = '拔高'
        self.__dict0__['管理'] = '治理'
        self.__dict0__['可以'] = '能够'
        self.__dict0__['核心'] = '重心'
        self.__dict0__['深入'] = '深刻'
        self.__dict0__['目标'] = '宗旨'
        self.__dict0__['宣传'] = '宣扬'
        self.__dict0__['参考'] = '参阅'
        self.__dict0__['特点'] = '特性'
        self.__dict0__['成立'] = '确立'
        self.__dict0__['培养'] = '培育'
        self.__dict0__['考察'] = '审查'
        self.__dict0__['邀请'] = '诚邀'
        self.__dict0__['检查'] = '稽查'
        self.__dict0__['全面'] = '通盘'
        self.__dict0__['解答'] = '解读回答'
        self.__dict0__['提供'] = '供予'
        self.__dict0__['提升'] = '拔高'
        self.__dict0__['非常'] = '甚是'
        self.__dict0__['我们'] = '俺们'
        self.__dict0__['目的'] = '宗旨'

        # self.__dict0__['选择题']='选择题目'
        # self.__dict0__['了']=''
        # self.__dict0__['有']='拥有'

    #         self.__dict0__['则'] = '那么'
    # #         self.__dict0__['为'] = '是'
    # #         self.__dict0__['那么'] = '则'
    #         self.__dict0__['中'] = '之中'
    #         self.__dict0__['若'] = '如果'
    #         # self.__dict0__['解答题']='解答题目'
    #         self.__dict0__['公路'] = '道路'
    #         self.__dict0__['已知'] = '已经知道'
    #         self.__dict0__['图像'] = '图形'
    #         self.__dict0__['图象'] = '图形'
    #         self.__dict0__['根据'] = '依照'
    #         self.__dict0__['练习'] = '演练'
    #         self.__dict0__['训练']='演练'
    #         self.__dict0__['解析式']='表达式'
    #         self.__dict0__['个人']='人员'
    #         self.__dict0__['年终']='年尾'
    #         self.__dict0__['工作总结']='工作梳理'
    #         self.__dict0__['工作计划']='劳动计划'
    #         self.__dict0__['忙忙碌碌']='马不停蹄'
    #         self.__dict0__['公司']='企事业单位'
    #         self.__dict0__['担任']='负责任职'
    #         self.__dict0__['部门']='团队组织'
    #         self.__dict0__['非常']='异常'
    #         self.__dict0__['感觉']='认为'
    #         self.__dict0__['工作']='任职事务'
    #         self.__dict0__['目的']='目标'
    #         self.__dict0__['教训']='失败或痛苦'
    #         self.__dict0__['提高']='提升'
    #         self.__dict0__['做']='作'
    #         self.__dict0__['更好']='更优'
    #         self.__dict0__['简要']='扼要'
    #         self.__dict0__['不足']='缺陷'
    #         self.__dict0__['效率']='效果'
    #         self.__dict0__['特点']='特性'
    #         self.__dict0__['全面']='全盘'
    #         self.__dict0__['教育']='教导'
    #         self.__dict0__['扎实']='踏实'
    #         self.__dict0__['思想']='思维'
    #         self.__dict0__['更新']='刷新'
    #         self.__dict0__['狠抓']='严抓'
    #         self.__dict0__['主要']='关键'
    #         self.__dict0__['学校']='校园'
    #         self.__dict0__['基本']='基础'

    #         self.__dict0__['教学']='教育'
    #         self.__dict0__['工作']='作业'
    #         self.__dict0__['事情']='作业'
    #         self.__dict0__['很多']='许多'
    #         self.__dict0__['通过']='经过'
    #         self.__dict0__['努力']='尽力'
    #         self.__dict0__['只有']='只要'
    #         self.__dict0__['就是']='便是'
    #         self.__dict0__['感受']='感触'
    #         self.__dict0__['原则']='准则'
    #         self.__dict0__['能力']='才能'
    #         self.__dict0__['提高']='进步'
    #         self.__dict0__['管理']='办理'
    #         self.__dict0__['确保']='保证'
    #         self.__dict0__['贯彻']='遵循'
    #         self.__dict0__['制度']='准则'
    #         self.__dict0__['思想']='思维'
    #         self.__dict0__['素养']='本质'
    #         self.__dict0__['核心']='中心'
    #         self.__dict0__['基']='根'
    #         self.__dict0__['深入']='深化'
    #         self.__dict0__['目标']='方针'
    #         self.__dict0__['建设']='建造'
    #         self.__dict0__['办好']='办妥'
    #         self.__dict0__['宣传']='宣扬'
    #         self.__dict0__['渗透']='浸透'
    #         self.__dict0__['寝室']='睡房'
    #         self.__dict0__['战斗']='战役'
    #         self.__dict0__['成立']='树立'
    #         self.__dict0__['培养']='培育'
    #         self.__dict0__['考察']='调查'
    #         self.__dict0__['示范']='演示'
    #         self.__dict0__['责任']='职责'
    #         self.__dict0__['组织']='安排'
    #         self.__dict0__['契机']='关键'
    #         self.__dict0__['认识']='知道'
    #         self.__dict0__['邀请']='邀约'
    #         self.__dict0__['内外']='表里'
    #         self.__dict0__['检查']='查看'
    #         self.__dict0__['辅导']='教导'
    #         self.__dict0__['建立']='树立'
    #         self.__dict0__['互助']='合作'
    #         self.__dict0__['老师']='教师'
    #         self.__dict0__['解答']='回答'
    #         self.__dict0__['沟通']='交流'
    #         self.__dict0__['反馈']='反映'
    #         self.__dict0__['召开']='举行'
    #         self.__dict0__['依靠']='依托'
    #         self.__dict0__['提升']='提高'
    #         self.__dict0__['毕业']='结业'
    #         self.__dict0__['事务']='业务'
    #         self.__dict0__['整理']='收拾'
    #         self.__dict0__['联系']='联络'
    #         self.__dict0__['提供']='供给'
    #         self.__dict0__['参考']='参阅'
    #         self.__dict0__['材料']='资料'
    #         self.__dict0__['时时']='不时'
    #         self.__dict0__['规范']='标准'
    #         self.__dict0__['记录']='记载'
    #         self.__dict0__['谈话']='说话'
    #         self.__dict0__['任务']='使命'
    #         self.__dict0__['一样']='相同'
    #         self.__dict0__['繁重']='深重'
    #         self.__dict0__['我们']='咱们'
    #         self.__dict0__['需要']='需求'
    #         self.__dict0__['可以']='能够'
    #         self.__dict0__['时间']='时刻'
    #         self.__dict0__['就是']='便是'
    #         self.__dict0__['锻炼']='训练'
    #         self.__dict0__['以后']='今后'

    # dict0

    def append_doc(self):
        for file in os.listdir(self.__path__):
            # file = file.decode('gbk')
            # 排除文件夹内的其它干扰文件，只获取".doc"后缀的word文件
            # if file.endswith(".docx"):
            self.__files__.append(self.__path__ + file)
            # print("doc文档：")
            # print(files)
        return self.__files__

    # 修改文档
    def contentModify(self, file):
        try:
            docx = Document(file)
            # 【1】修改关键字
            """
                遍历word中的所有 paragraphs，在每一段中发现含有key 的内容，就替换为 value 。 
                （key 和 value 都是replace_dict中的键值对。）
            """
            for para in docx.paragraphs:
                for i in range(len(para.runs)):
                    if i == 1:
                        para.runs[i].text = ""
                    # for key, value in self.__dict0__.items():
                    #     if key in para.runs[i].text:
                    #         # print(key + "-->" + value)
                    #         para.runs[i].text = para.runs[i].text.replace(key, value)

            #             # 修改段落距离等信息
            #             # 较大范围内的修改必须在尾部，在首部修改无效
            #             # 【2】修改段间距，以榜为单位
            #             pars=docx.paragraphs
            #             for par in pars:
            #                 if par.style.name=="Heading 1":
            #                     par.paragraph_format.space_before = Pt(18)
            #                     par.paragraph_format.space_after =Pt(18)
            #                 # 【3】段落首行缩进
            #                 par.paragraph_format.first_line_indent = Inches(0.25)
            #                 #  【4】段落对齐方式
            #                 # LEFT      =>  左对齐
            #                 # CENTER    =>  文字居中
            #                 # RIGHT     =>  右对齐
            #                 # JUSTIFY   =>  文本两端对齐
            #                 par.paragraph_format.alignment = WD_ALIGN_PARAGRAPH.JUSTIFY
            #                 # 【5】段落行距
            #                 #SINGLE         =>  单倍行距（默认）
            #                 #ONE_POINT_FIVE =>  1.5倍行距
            #                 #DOUBLE2        =>  倍行距
            #                 #AT_LEAST       =>  最小值
            #                 #EXACTLY        =>  固定值
            #                 #MULTIPLE       =>  多倍行距
            #                 par.line_spacing_rule = WD_LINE_SPACING.MULTIPLE #多倍行距
            #                 par.paragraph_format.line_spacing = 1.75 # 1.75倍行间距

            #             # 修改字体信息
            #             # 【6】 修改正文的中文字体大小，字体类型无法修改
            #             docx.styles['Normal'].font.name = u'微软雅黑'
            #             docx.styles['Normal']._element.rPr.rFonts.set(qn('w:eastAsia'), u'微软雅黑')
            #             docx.styles['Normal'].font.size = Pt(12.8)
            #         保存文档
            docx.save(self.__mkdir_path__ + '/' + os.path.basename(file))
        except:
            #             print(1)
            pass


if __name__ == "__main__":
    #     print(2)
    list_filename = []
    doc = Documents()
    list_filename = doc.append_doc()

    # 线程池法，可在线程池中调用类函数doc.convert_docx
    time_start = time.time()
    #     print(2)
    pool = Threadpool(5)
    #     print(3)
    pool.map(doc.contentModify, list_filename)
    pool.close()
    pool.join()
    time_end = time.time()
    word = wc.Dispatch("kwps.Application")
    word.Quit()
    print("完成，用时", time_end - time_start, "s")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-f0baac5243ba> in <module>()
#       5 reload(sys)
#       6 sys.setdefaultencoding('utf8')
# ----> 7 from docx import Document
#       8 from docx.shared import RGBColor, Pt, Cm, Inches
#       9 import os
#
# ImportError: No module named docx

# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-32886514c262> in <module>()
# ----> 1 python
#
# NameError: name 'python' is not defined
